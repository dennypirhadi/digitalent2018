# %%
import os
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %%
# sql = 'select * from employees'
sql = 'show tables'

run(sql)
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %%
sql = "SELECT CONCAT(firstName,' ',lastName) AS fullName FROM employees"

run(sql)
# Out:
#              fullName
# 0        Diane Murphy
# 1      Mary Patterson
# 2       Jeff Firrelli
# 3   William Patterson
# 4       Gerard Bondur
# 5         Anthony Bow
# 6     Leslie Jennings
# 7     Leslie Thompson
# 8      Julie Firrelli
# 9     Steve Patterson
# 10     Foon Yue Tseng
# 11      George Vanauf
# 12        Loui Bondur
# 13   Gerard Hernandez
# 14    Pamela Castillo
# 15         Larry Bott
# 16        Barry Jones
# 17        Andy Fixter
# 18        Peter Marsh
# 19           Tom King
# 20         Mami Nishi
# 21       Yoshimi Kato
# 22      Martin Gerard

# %%
sql = 'SELECT orderNumber,YEAR(orderDate),MONTH(orderDate),DAY(orderDate) FROM orders'

run(sql)
# Out:
#      orderNumber  YEAR(orderDate)  MONTH(orderDate)  DAY(orderDate)
# 0          10100             2003                 1               6
# 1          10101             2003                 1               9
# 2          10102             2003                 1              10
# 3          10103             2003                 1              29
# 4          10104             2003                 1              31
# 5          10105             2003                 2              11
# 6          10106             2003                 2              17
# 7          10107             2003                 2              24
# 8          10108             2003                 3               3
# 9          10109             2003                 3              10
# 10         10110             2003                 3              18
# 11         10111             2003                 3              25
# 12         10112             2003                 3              24
# ...

# %%
# DISTINCT : Lihat Perbedaan dari Query dibawah ini
# run("SELECT lastName FROM employees")
run("SELECT DISTINCT lastName FROM employees")
# Out:
#      lastName
# 0      Murphy
# 1   Patterson
# 2    Firrelli
# 3      Bondur
# 4         Bow
# 5    Jennings
# 6    Thompson
# 7       Tseng
# 8      Vanauf
# 9   Hernandez
# 10   Castillo
# 11       Bott
# 12      Jones
# 13     Fixter
# 14      Marsh
# 15       King
# 16      Nishi
# 17       Kato
# 18     Gerard

# %% [markdown]
# # 2. Kondisi dengan WHERE

# %%
sql = """SELECT   customername,
         country,
         state,
         creditlimit
FROM customers
WHERE country = 'USA'
        AND state = 'CA'
        AND creditlimit > 100000"""

run(sql)
# Out:
#                    customername country state  creditlimit
# 0  Mini Gifts Distributors Ltd.     USA    CA     210500.0
# 1  Collectable Mini Designs Co.     USA    CA     105000.0
# 2      Corporate Gift Ideas Co.     USA    CA     105000.0

# %%
sql = "SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle='Sales Rep' AND officeCode=1"

run(sql)
# Out:
#   firstName  lastName   jobTitle officeCode
# 0    Leslie  Jennings  Sales Rep          1
# 1    Leslie  Thompson  Sales Rep          1

# %%
sql = """select * from orders 
          where orderdate between '2003-01-06' and '2003-01-29'
        """

run(sql)
# Out:
#    orderNumber   orderDate requiredDate shippedDate   status  \
# 0        10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1        10101  2003-01-09   2003-01-18  2003-01-11  Shipped
# 2        10102  2003-01-10   2003-01-18  2003-01-14  Shipped
# 3        10103  2003-01-29   2003-02-07  2003-02-02  Shipped
#
#                  comments  customerNumber
# 0                    None             363
# 1  Check on availability.             128
# 2                    None             181
# 3                    None             121

# %% [markdown]
# # 3. Mengurutkan Hasil dengan Order By

# %%
sql = "SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice"

run(sql)
# Out:
#                                     productName       productLine  buyPrice
# 0                       1970 Plymouth Hemi Cuda      Classic Cars     31.92
# 1                         1961 Chevrolet Impala      Classic Cars     32.33
# 2                            1970 Dodge Coronet      Classic Cars     32.37
# 3                         1957 Ford Thunderbird      Classic Cars     34.21
# 4                     1971 Alpine Renault 1600s      Classic Cars     38.58
# 5                               1982 Camaro Z28      Classic Cars     46.53
# 6                            1949 Jaguar XK 120      Classic Cars     47.25
# 7                          1969 Dodge Super Bee      Classic Cars     49.05
# 8                    1970 Chevy Chevelle SS 454      Classic Cars     49.24
# 9                     1969 Chevrolet Camaro Z28      Classic Cars     50.51
# 10                  1948 Porsche 356-A Roadster      Classic Cars     53.90
# ...

# %% [markdown]
# # 4. Membatasi Hasil Dengan Limit

# %%
sql = "SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice LIMIT 10,10"

run(sql)
# Out:
#                          productName   productLine  buyPrice
# 0        1948 Porsche 356-A Roadster  Classic Cars     53.90
# 1       1999 Indy 500 Monte Carlo SS  Classic Cars     56.76
# 2                  1985 Toyota Supra  Classic Cars     57.01
# 3                 1969 Dodge Charger  Classic Cars     58.73
# 4                2002 Chevy Corvette  Classic Cars     62.11
# 5     1948 Porsche Type 356 Roadster  Classic Cars     62.16
# 6              1965 Aston Martin DB5  Classic Cars     65.96
# 7  1992 Porsche Cayenne Turbo Silver  Classic Cars     69.78
# 8          1957 Corvette Convertible  Classic Cars     69.93
# 9                  1952 Citroen-15CV  Classic Cars     72.82

# %% [markdown]
# # 5. Pencarian String

# %%
sql = """
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    firstName LIKE 'a%'
"""

run(sql)
# Out:
#    employeeNumber lastName firstName
# 0            1143      Bow   Anthony
# 1            1611   Fixter      Andy

# %%
sql ="""
SELECT 
    productCode, 
    productName
FROM
    products
WHERE
    productCode LIKE '%\_20%';
"""

run(sql)
# Out:
#   productCode                                productName
# 0    S10_2016                      1996 Moto Guzzi 1100i
# 1    S24_2000                   1960 BSA Gold Star DBD34
# 2    S24_2011                      18th century schooner
# 3    S24_2022  1938 Cadillac V-16 Presidential Limousine
# 4   S700_2047                                 HMS Bounty

# %%
sql = """
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    firstName LIKE 'a%'
"""

run(sql)
# Out:
#    employeeNumber lastName firstName
# 0            1143      Bow   Anthony
# 1            1611   Fixter      Andy

# %%
sql = """
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    firstname LIKE 'T_m'
"""

run(sql)
# Out:
#    employeeNumber lastName firstName
# 0            1619     King       Tom

# %% [markdown]
# # 6. Aggregasi

# %%
sql = """
SELECT 
    YEAR(paymentDate) AS Tahun,
    MONTH(paymentDate) AS Bulan,
    SUM(amount) AS TotalBayar 
FROM payments 
GROUP BY Tahun,Bulan
HAVING TotalBayar > 300000
ORDER BY TotalBayar DESC
"""

run(sql)
# Out:
#    Tahun  Bulan  TotalBayar
# 0   2004     11   857187.30
# 1   2003     12   826637.64
# 2   2004     12   819285.62
# 3   2003     11   694292.68
# 4   2004      9   476445.53
# 5   2004      3   404603.21
# 6   2005      3   385268.09
# 7   2004      8   378094.30
# 8   2003     10   316857.96

# %%
sql = """ select year(paymentdate) tahun, month(paymentdate) bulan, sum(amount) totalbayar
    FROM payments 
GROUP BY Tahun,Bulan
HAVING TotalBayar > 300000
ORDER BY TotalBayar DESC
LIMIT 5
"""

run(sql)
# Out:
#    tahun  bulan  totalbayar
# 0   2004     11   857187.30
# 1   2003     12   826637.64
# 2   2004     12   819285.62
# 3   2003     11   694292.68
# 4   2004      9   476445.53
