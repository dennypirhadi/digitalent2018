# %%
import os
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ## 1. Prepare a list of offices sorted by country, state, city.

# %%
sql = 'select * from offices order by country, state, city'

run(sql)
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# ## 2. How many employees are there in the company?

# %%
sql = 'select count(1) emp_count from employees'

run(sql)
# Out:
#    emp_count
# 0         23

# %% [markdown]
# ## 3. What is the total of payments received?

# %%
sql = 'select sum(amount) from payments'

run(sql)
# Out:
#    sum(amount)
# 0   8853839.23

# %% [markdown]
# ## 4. List the product lines that contain 'Cars'.

# %%
sql = "select * from products where productline LIKE '%cars%'"

run(sql)
# Out:
#    productCode                                productName   productLine  \
# 0     S10_1949                   1952 Alpine Renault 1300  Classic Cars
# 1     S10_4757                        1972 Alfa Romeo GTA  Classic Cars
# 2     S10_4962                     1962 LanciaA Delta 16V  Classic Cars
# 3     S12_1099                          1968 Ford Mustang  Classic Cars
# 4     S12_1108                          2001 Ferrari Enzo  Classic Cars
# 5     S12_3148                         1969 Corvair Monza  Classic Cars
# 6     S12_3380                         1968 Dodge Charger  Classic Cars
# 7     S12_3891                           1969 Ford Falcon  Classic Cars
# 8     S12_3990                    1970 Plymouth Hemi Cuda  Classic Cars
# 9     S12_4675                         1969 Dodge Charger  Classic Cars
# 10    S18_1129                            1993 Mazda RX-7  Classic Cars
# 11    S18_1342                       1937 Lincoln Berline  Vintage Cars
# ...

# %% [markdown]
# ## 5.Report total payments for October 28, 2004

# %%
sql = "select sum(amount) from payments where paymentdate = '2004-10-28'"

run(sql)
# Out:
#    sum(amount)
# 0     47411.33

# %% [markdown]
# ## 6. Report those payments greater than 100,000.

# %%
sql = 'select * from payments where amount > 100000'

run(sql)
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# ## 7. List the products in each product line

# %%
sql = 'select productline,productname from products group by productline, productname'

run(sql)
# Out:
#           productline                                  productname
# 0        Classic Cars                  1948 Porsche 356-A Roadster
# 1        Classic Cars               1948 Porsche Type 356 Roadster
# 2        Classic Cars                           1949 Jaguar XK 120
# 3        Classic Cars                     1952 Alpine Renault 1300
# 4        Classic Cars                            1952 Citroen-15CV
# 5        Classic Cars                      1956 Porsche 356A Coupe
# 6        Classic Cars                    1957 Corvette Convertible
# 7        Classic Cars                        1957 Ford Thunderbird
# 8        Classic Cars          1958 Chevy Corvette Limited Edition
# 9        Classic Cars                        1961 Chevrolet Impala
# 10       Classic Cars                       1962 LanciaA Delta 16V
# 11       Classic Cars                        1965 Aston Martin DB5
# 12       Classic Cars                    1966 Shelby Cobra 427 S/C
# ...

# %% [markdown]
# ## 8. How many products in each product line?

# %%
sql = 'select productline,count(1) from products group by productline'

run(sql)
# Out:
#         productline  count(1)
# 0      Classic Cars        38
# 1       Motorcycles        13
# 2            Planes        12
# 3             Ships         9
# 4            Trains         3
# 5  Trucks and Buses        11
# 6      Vintage Cars        24

# %% [markdown]
# ## 9. What is the minimum payment received?

# %%
sql = 'select min(amount) from payments'

run(sql)
# Out:
#    min(amount)
# 0       615.45

# %% [markdown]
# ## 10. List all payments greater than twice the average payment.

# %%
sql = 'select * from payments where amount > 2*(select avg(amount) from payments)'

run(sql)
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %% [markdown]
# ## 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
sql = 'select avg((msrp-buyprice)/buyprice) from products'

run(sql)
# Out:
#    avg((msrp-buyprice)/buyprice)
# 0                       0.887024

# %% [markdown]
# ## 12. How many distinct products does ClassicModels sell?

# %%
sql = "select count(distinct productname) from products"

run(sql)
# Out:
#    count(distinct productname)
# 0                          110

# %% [markdown]
# ## 13. Report the name and city of customers who don't have sales representatives?

# %%
sql = "select concat(contactFirstname, ' ', contactLastName) FullName, city from customers where salesrepemployeenumber is null"

run(sql)
# Out:
#                     FullName              city
# 0   Zbyszek  Piestrzeniewicz          Warszawa
# 1          Isabel  de Castro            Lisboa
# 2              Brydey Walker         Singapore
# 3               Horst  Kloss         Cunewalde
# 4          Alejandra  Camino            Madrid
# 5            Renate  Messner         Frankfurt
# 6             Peter  Franken           München
# 7                Ed Harrison          Fribourg
# 8           Bradley Schuyler         Amsterdam
# 9               Mel Andersen            Berlin
# 10            Philip  Cramer       Brandenburg
# 11         Patricia  McKenna              Cork
# 12              Armand Kuger          Hatfield
# 13             Karin Josephs           Münster
# 14           Lino  Rodriguez            Lisboa
# 15              Rita  Müller         Stuttgart
# 16          Alexander  Feuer           Leipzig
# 17             Sven  Ottlieb            Aachen
# 18              Carmen Anton            Madrid
# ...

# %% [markdown]
# ## 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
sql = "select concat(firstname, ' ', lastname) FullName, jobtitle from employees where jobtitle LIKE 'vp%' or jobtitle LIKE '%manager%'"

run(sql)
# Out:
#             FullName              jobtitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# ## 15. Which orders have a value greater than 5,000?

# %%
sql = """ select ordernumber, sum(quantityordered*priceeach) total from orderdetails group by ordernumber
having total > 5000 order by total"""


run(sql)
# Out:
#      ordernumber     total
# 0          10102   5494.78
# 1          10216   5759.42
# 2          10422   5849.44
# 3          10290   5858.56
# 4          10236   5899.38
# 5          10130   6036.96
# 6          10298   6066.78
# 7          10243   6276.60
# 8          10269   6419.84
# 9          10335   6466.44
# 10         10146   6631.36
# 11         10233   7178.66
# 12         10213   7310.42
# 13         10323   7466.32
# 14         10125   7565.08
# 15         10218   7612.06
# 16         10421   7639.10
# 17         10112   7674.94
# 18         10199   7678.25
# 19         10365   8307.28
# 20         10423   8597.73
# 21         10392   8807.12
# 22         10265   9415.13
# 23         10352   9658.74
# 24         10152   9821.32
# 25         10166   9977.85
# 26         10100  10223.83
# 27         10101  10549.01
# 28         10190  10721.86
# 29         10415  10945.26
# ..           ...       ...
# 273        10122  50824.66
# 274        10108  51001.22
# ...
