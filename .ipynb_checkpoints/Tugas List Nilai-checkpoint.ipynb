# %% [markdown]
# # LATIHAN 2 - Tugas List Nilai
#
# Diberikan sekumpulan Nilai Random antara 0 sampai dengan 100 sebanyak 250 nilai. Buatlah program untuk melakukan hal berikut:
#
# 1. Tampilkan Angka Ganjil dari ke 250 nilai tersebut
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut
# 4. Tampilkan nilai maksimum dan minimum
# 5. Tampilkan modus dari sekumpulan nilai tersebut

# %%
import random
import math
import statistics

# GENERATE RANDOM
nilaiTugas = []
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print("List Nilai Tugas = ", nilaiTugas)

# TAMPILKAN:

# ganjil
nilaiGanjil = []
for n in nilaiTugas:
    if n%2 == 1:
        nilaiGanjil.append(n)
print("\nList Nilai Ganjil = ",nilaiGanjil)
#print('\nJumlah Nilai Ganjil = ', len(nilaiGanjil))

# nilai > 70
nilaiGT70 = []
for n in nilaiTugas:
    if n > 70:
        nilaiGT70.append(n)
#print('\nList Nilai > 70 = ',nilaiGT70)
print('\nJumlah Nilai > 70 = ', len(nilaiGT70))

# standar deviasi
def hitung_sd(data):
    n = len(data)

    if n <= 1:
        return 0.0

    rerata, sd = hitung_rerata(data), 0.0

    # hitung st dev.
    for i in data:
        sd += (i - rerata)**2
    sd = math.sqrt(sd / (n-1))

    return sd

def hitung_rerata(ls):
    n, total = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # hitung rerata
    for i in ls:
        total += i
    rerata = total / n

    return rerata

nilaiSD = hitung_sd(nilaiTugas)
print('\nNilai Standard Deviasi = ', nilaiSD)

sd_stats = statistics.stdev(nilaiTugas)
print('\nNilai Standard Deviasi = ', sd_stats)

# maksimum
nilaiTugas.sort()
print('\nNilai Maksimum = ',nilaiTugas[-1])

# minimum
print('\nNilai Minimum = ',nilaiTugas[0])

# modus
setKeys = set(nilaiTugas)
#print(setKeys)
#print(len(setKeys))
listKeys = list(setKeys)

maxCount = 0
modusList = []
dictNilai = {}

for i in listKeys:
    keyCount = nilaiTugas.count(i)
    dictNilai[i] = keyCount
    if keyCount>maxCount:
        maxCount = keyCount
      
for k,v in dictNilai.items():
    if v==maxCount:
        modusList.append(k)
        
print('\nDictionary Nilai dan Counter = ',dictNilai)
print('\nJumlah Kemunculan Terbanyak = ', maxCount)
print('\nList Nilai Modus = ', modusList)
# Out:
# List Nilai Tugas =  [91, 53, 44, 22, 44, 55, 36, 77, 17, 64, 97, 5, 51, 41, 46, 76, 6, 14, 94, 86, 74, 49, 52, 78, 48, 55, 5, 86, 60, 86, 7, 41, 26, 42, 89, 96, 83, 18, 38, 25, 26, 59, 31, 51, 2, 76, 79, 74, 17, 23, 29, 4, 29, 98, 79, 5, 19, 40, 46, 73, 44, 26, 54, 21, 44, 56, 2, 82, 31, 73, 40, 45, 90, 49, 44, 78, 1, 57, 12, 34, 10, 1, 65, 17, 75, 18, 39, 76, 19, 86, 7, 74, 75, 79, 39, 10, 41, 36, 88, 12, 64, 42, 43, 47, 17, 68, 46, 47, 56, 12, 55, 10, 17, 3, 68, 99, 87, 16, 49, 80, 25, 69, 34, 37, 12, 24, 32, 57, 6, 93, 60, 53, 63, 14, 19, 95, 7, 80, 22, 78, 54, 53, 80, 77, 70, 49, 12, 65, 26, 43, 55, 93, 90, 30, 89, 4, 82, 15, 97, 72, 74, 33, 21, 3, 94, 49, 60, 27, 25, 61, 81, 81, 4, 67, 69, 78, 80, 68, 35, 48, 14, 4, 82, 35, 58, 17, 4, 96, 91, 96, 41, 93, 3, 4, 9, 81, 52, 33, 16, 74, 5, 32, 35, 83, 23, 40, 65, 17, 64, 47, 32, 12, 85, 49, 81, 33, 66, 34, 60, 33, 25, 37, 85, 86, 40, 20, 56, 64, 47, 72, 1, 20, 50, 41, 4, 98, 52, 46, 66, 44, 35, 61, 46, 10, 11, 35, 11, 51, 74, 43]
#
# ...
